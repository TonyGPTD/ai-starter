# %% [markdown]
# # ex1_scientific1
#
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 to 15 point radii
# Out:
# CPU times: user 2 μs, sys: 1 μs, total: 3 μs
# Wall time: 5.48 μs

# %% [markdown]
# # Mã kiểm tra dữ liệu

# %%
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples[{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples[{area[0:10]}]')
# Out:
# + x: len=50, [0.10, 1.00]: 10 samples [[0.70033936 0.12869187 0.62427945 0.28319276 0.37546272 0.43100631
#  0.29219371 0.31652896 0.43203273 0.99274794]]
# + y: len=50, [0.04, 0.98]: 10 samples [[0.75272554 0.89030736 0.26215486 0.90516828 0.95767414 0.26821838
#  0.54386093 0.64933086 0.82366176 0.72378894]]
# + colors: len=50, [0.02, 1.00]: 10 samples[[0.40287338 0.24151224 0.04262748 0.02803124 0.47504956 0.95706058
#  0.81552609 0.30555286 0.9988461  0.27012152]]
# + area: len=50, [0.05, 693.21]: 10 samples[[666.15811583 687.69166019 555.78649727   4.81698747   4.82305245
#   86.32163866 292.86073467   3.26991571 258.29690129   9.35687107]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## Kết thúc
